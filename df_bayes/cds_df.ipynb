# %% [markdown]
# ## CDS Assignment
#
# #### Dataframe Creation

# %%
import pandas as pd
import numpy as np
import re

# %%
# instantiate main dataframe, df

df = pd.DataFrame()

df['Dx ID'] = 0
df['Mx ID'] = 0
df['Dx Mx Association'] = 0
df['Dx Name'] = 0
#df['Dx Prevalence'] = 0 # we'll merge() this later
df['Mx Name'] = 0
df['Mx PPV'] = 0
df['Mx Sensitivity'] = 0
#df['Mx Import'] = 0 # we'll merge() this later
df['Specificity'] = 0
df['LR (+)'] = 0
df['LR (-)'] = 0

df
# Out:
# Empty DataFrame
# Columns: [Dx ID, Mx ID, Dx Mx Association, Dx Name, Mx Name, Mx PPV, Mx Sensitivity, Specificity, LR (+), LR (-)]
# Index: []

# %%
# incorporate the associations between Dx and Mx
df_DxMx = pd.read_csv('dx_mx_associations.txt', sep='\t', names=['dx', 'mx'])
df_DxMx.head()
# Out:
#                       dx                                                 mx
# 0  DX 362  PEPTIC ULCER   MX 34 59 ABDOMEN PAIN EPIGASTRIUM RECURRENT AT...
# 1  DX 362  PEPTIC ULCER       MX 22 62 ABDOMEN PAIN EPIGASTRIUM SEASONAL HX
# 2  DX 362  PEPTIC ULCER     MX 23 64 ABDOMEN PAIN EXACERBATION WITH ALCOHOL
# 3  DX 362  PEPTIC ULCER                              MX 02 198 AGE 16 TO 25
# 4  DX 362  PEPTIC ULCER                              MX 03 199 AGE 26 TO 55

# %%
# read Dx Mx file

f = open('dx_mx_associations.txt')
lines = f.readlines()
f.close

lines[:5]
# Out:
# ['DX 362  PEPTIC ULCER \tMX 34 59 ABDOMEN PAIN EPIGASTRIUM RECURRENT ATTACK <S> HX\n',
#  'DX 362  PEPTIC ULCER \tMX 22 62 ABDOMEN PAIN EPIGASTRIUM SEASONAL HX\n',
#  'DX 362  PEPTIC ULCER \tMX 23 64 ABDOMEN PAIN EXACERBATION WITH ALCOHOL\n',
#  'DX 362  PEPTIC ULCER \tMX 02 198 AGE 16 TO 25\n',
#  'DX 362  PEPTIC ULCER \tMX 03 199 AGE 26 TO 55\n']

# %%
# group the Dx ID, Dx name, Dx prevalence, Mx ID, Mx name, Mx PPV, and Mx Sensitivity

m = re.compile(r'DX\s(\d+)\s+(.+)\s\sMX\s(\d)(\d)\s(\d+)\s(.+)')

dx_id = []
dx_name = []
mx_id = []
mx_name = []
mx_ppv = []
mx_sens = []

for i in range(len(lines)):
    dx_id.append((m.match(lines[i]).group(1)))
    dx_name.append((m.match(lines[i]).group(2)))
    mx_id.append((m.match(lines[i]).group(5)))
    mx_name.append((m.match(lines[i]).group(6)))
    mx_ppv.append((m.match(lines[i]).group(3)))
    mx_sens.append((m.match(lines[i]).group(4)))

# %%
# combine Dx and Mx IDs for associations column

dx_mx = []

for i in range(len(dx_id)):
    dx_mx.append(dx_id[i] + ', ' + mx_id[i])
    
dx_mx[:5]
# Out:
# ['362, 59', '362, 62', '362, 64', '362, 198', '362, 199']

# %%
# incorporate prevalence table
df_prev = pd.read_csv('dx_prev.txt', sep='\t')

# Grayson, I'm renaming these columns to make a merge simpler in a future step
df_prev.rename(index=str, columns={"id": "Dx ID", "prev": "Dx Prevalence", "name": "Dx Name"}, inplace=True)

# Grayson, I'm also coercing the index to a string to be consistent with the 
# df dataframe you created
df_prev['Dx ID'] = df_prev['Dx ID'].apply(str)
df_prev.head()
# Out:
#   Dx ID  Dx Prevalence                                    Dx Name
# 0   114              3                        choledocholithiasis
# 1   362              5                               peptic ulcer
# 2   441              2                        pyloric obstruction
# 3   187              3                          gastric carcinoma
# 4   189              2  gastritis giant hypertrophic <menetriers>

# %%
# incorporate import numbers
f = open('mx.txt')
lines = f.readlines()
lines[:5]
# Out:
# ['MX 100 ABDOMEN SURGERY RECENT HX    IM  1 TY 1 \n',
#  'MX 1001 COLON BARIUM ENEMA WALL THICKENED   IM  3 TY 5 \n',
#  'MX 1005 COLONOSCOPY BIOPSY GRANULOMA S NON CASEATING   IM  4 TY 6 \n',
#  'MX 1012 COLONOSCOPY MULTIPLE NODULAR FILLING DEFECT S   IM  4 TY 6 \n',
#  'MX 102 ABDOMEN TENDERNESS EPIGASTRIUM NON HEPATIC   IM  3 TY 3 \n']

# %%
# group the Mx ID numbers and import numbers

m = re.compile(r'MX\s(\d+).+IM\s+(\d)')

mx_import_id = []
mx_import_num = []

for i in range(len(lines)):
    mx_import_id.append((m.match(lines[i]).group(1)))
    mx_import_num.append((m.match(lines[i]).group(2)))

# %%
# create dataframe for imports
df_mx_import = pd.DataFrame()
df_mx_import['Mx ID'] = mx_import_id
df_mx_import['Import Num'] = mx_import_num

# %%
df_mx_import.tail()
# Out:
#     Mx ID Import Num
# 348   980          3
# 349   982          4
# 350   985          3
# 351   989          4
# 352   998          3

# %% [markdown]
# #### Add everything to df

# %%
# put associations, Dx name, Mx name, PPV, and sensitivity into df

df['Dx ID'] = dx_id
df['Mx ID'] = mx_id
df['Dx Mx Association'] = dx_mx
df['Dx Name'] = dx_name
df['Mx Name'] = mx_name
df['Mx PPV'] = mx_ppv
df['Mx Sensitivity'] = mx_sens

df.head()
# Out:
#   Dx ID Mx ID Dx Mx Association       Dx Name  \
# 0   362    59           362, 59  PEPTIC ULCER
# 1   362    62           362, 62  PEPTIC ULCER
# 2   362    64           362, 64  PEPTIC ULCER
# 3   362   198          362, 198  PEPTIC ULCER
# 4   362   199          362, 199  PEPTIC ULCER
#
#                                             Mx Name Mx PPV Mx Sensitivity  \
# 0  ABDOMEN PAIN EPIGASTRIUM RECURRENT ATTACK <S> HX      3              4
# 1              ABDOMEN PAIN EPIGASTRIUM SEASONAL HX      2              2
# 2            ABDOMEN PAIN EXACERBATION WITH ALCOHOL      2              3
# 3                                      AGE 16 TO 25      0              2
# 4                                      AGE 26 TO 55      0              3
#
#    Specificity  LR (+)  LR (-)
# 0          NaN     NaN     NaN
# 1          NaN     NaN     NaN
# 2          NaN     NaN     NaN
# 3          NaN     NaN     NaN
# 4          NaN     NaN     NaN

# %%
# add import numbers
#for i in range(len(df)):
#    for j in range(len(df_mx_import)):
#        if df['Mx ID'][i] == mx_import_id[j]:
#            df['Mx Import'][i] = mx_import_num[j]

# Grayson, you can do a simple 'merge'
# (using set theory) rather than a double for-loop
# should be much faster

df = pd.merge(df, df_mx_import, on='Mx ID')

# %%
# add prevalences
#for i in range(len(df)):
#    for j in range(len(df_prev)):
#        if int(df['Dx ID'][i]) == df_prev['id'][j]:
#            df['Dx Prevalence'][i] = df_prev['prev'][j]

df = pd.merge(df, df_prev[['Dx ID', 'Dx Prevalence']], on='Dx ID')

# %%
df.head()

df.to_csv('mxdx.csv')

# %%
# cast all numeric values to integers 

#for i in range(len(df)):  
#    df['Dx Prevalence'][i] = int(df['Dx Prevalence'][i])    
#    df['Mx PPV'][i] = int(df['Mx PPV'][i])    
#    df['Mx Sensitivity'][i] = int(df['Mx Sensitivity'][i])    
#    df['Mx Import'][i] = int(df['Mx Import'][i])    

# Grayson, here is a vectorized form that should be quicker
cols = ['Dx Prevalence', 'Mx PPV', 'Mx Sensitivity', 'Import Num']
df[cols] = df[cols].apply(pd.to_numeric)
df.head()
# Out:
#   Dx ID Mx ID Dx Mx Association       Dx Name  \
# 0   362    59           362, 59  PEPTIC ULCER
# 1   362    62           362, 62  PEPTIC ULCER
# 2   362    64           362, 64  PEPTIC ULCER
# 3   362   198          362, 198  PEPTIC ULCER
# 4   362   199          362, 199  PEPTIC ULCER
#
#                                             Mx Name  Mx PPV  Mx Sensitivity  \
# 0  ABDOMEN PAIN EPIGASTRIUM RECURRENT ATTACK <S> HX       3               4
# 1              ABDOMEN PAIN EPIGASTRIUM SEASONAL HX       2               2
# 2            ABDOMEN PAIN EXACERBATION WITH ALCOHOL       2               3
# 3                                      AGE 16 TO 25       0               2
# 4                                      AGE 26 TO 55       0               3
#
#    Specificity  LR (+)  LR (-)  Import Num  Dx Prevalence
# 0          NaN     NaN     NaN           2              5
# 1          NaN     NaN     NaN           2              5
# 2          NaN     NaN     NaN           2              5
# 3          NaN     NaN     NaN           3              5
# 4          NaN     NaN     NaN           3              5

# %%
#PREV = {1: 1/1000000,
#       2: 1/100000,
#       3: 1/1000,
#       4: 1/100,
#       5: 1/10}
PREV = {1: 1/1000000,
       2: 1/100000,
       3: 1/1000,
       4: 1/100,
       5: 1/15}

PPV = {0: np.NaN,
      1: 0.01,
      2: 0.1,
      3: 0.75,
      4: 0.9,
      5: 1}

SENS = {1: 0.01,
       2: 0.1,
       3: 0.5,
       4: 0.75,
       5: 1}

df['Dx Prevalence'] = df['Dx Prevalence'].map(PREV)
df['Mx PPV'] = df['Mx PPV'].map(PPV)
df['Mx Sensitivity'] = df['Mx Sensitivity'].map(SENS)

# %%
df.head()
# Out:
#   Dx ID Mx ID Dx Mx Association       Dx Name  \
# 0   362    59           362, 59  PEPTIC ULCER
# 1   362    62           362, 62  PEPTIC ULCER
# 2   362    64           362, 64  PEPTIC ULCER
# 3   362   198          362, 198  PEPTIC ULCER
# 4   362   199          362, 199  PEPTIC ULCER
#
#                                             Mx Name  Mx PPV  Mx Sensitivity  \
# 0  ABDOMEN PAIN EPIGASTRIUM RECURRENT ATTACK <S> HX    0.75            0.75
# 1              ABDOMEN PAIN EPIGASTRIUM SEASONAL HX    0.10            0.10
# 2            ABDOMEN PAIN EXACERBATION WITH ALCOHOL    0.10            0.50
# 3                                      AGE 16 TO 25     NaN            0.10
# 4                                      AGE 26 TO 55     NaN            0.50
#
#    Specificity  LR (+)  LR (-)  Import Num  Dx Prevalence
# 0          NaN     NaN     NaN           2       0.066667
# 1          NaN     NaN     NaN           2       0.066667
# 2          NaN     NaN     NaN           2       0.066667
# 3          NaN     NaN     NaN           3       0.066667
# 4          NaN     NaN     NaN           3       0.066667

# %%
# add specificity helper function

def calc_specificity(sens, ppv, prev):
    """
    Calculate specificity based on sensitivity, positive
    predictive value, & prevalence. 
    """
    spec = 1 - ((sens*prev/ppv - sens*prev)/(1-prev))
    return spec

# %%
# calculate specificities

#for i in range(len(df)):
#    df['Specificity'][i] = calc_specificity(df['Mx Sensitivity'][i], df['Mx PPV'][i], df['Dx Prevalence'][i])

# Grayson, here is vectorized notation coming into play again
df['Specificity'] = calc_specificity(df['Mx Sensitivity'], df['Mx PPV'], df['Dx Prevalence'])
df.head()
# Out:
#   Dx ID Mx ID Dx Mx Association       Dx Name  \
# 0   362    59           362, 59  PEPTIC ULCER
# 1   362    62           362, 62  PEPTIC ULCER
# 2   362    64           362, 64  PEPTIC ULCER
# 3   362   198          362, 198  PEPTIC ULCER
# 4   362   199          362, 199  PEPTIC ULCER
#
#                                             Mx Name  Mx PPV  Mx Sensitivity  \
# 0  ABDOMEN PAIN EPIGASTRIUM RECURRENT ATTACK <S> HX    0.75            0.75
# 1              ABDOMEN PAIN EPIGASTRIUM SEASONAL HX    0.10            0.10
# 2            ABDOMEN PAIN EXACERBATION WITH ALCOHOL    0.10            0.50
# 3                                      AGE 16 TO 25     NaN            0.10
# 4                                      AGE 26 TO 55     NaN            0.50
#
#    Specificity  LR (+)  LR (-)  Import Num  Dx Prevalence
# 0     0.982143     NaN     NaN           2       0.066667
# 1     0.935714     NaN     NaN           2       0.066667
# 2     0.678571     NaN     NaN           2       0.066667
# 3          NaN     NaN     NaN           3       0.066667
# 4          NaN     NaN     NaN           3       0.066667

# %%
#for i in range(len(df)):
#    df['LR (+)'][i] = df['Mx Sensitivity'][i]/(1-df['Specificity'][i])
#    df['LR (-)'][i] = (1-df['Mx Sensitivity'][i])/df['Specificity'][i]

def lr_pos(sens, spec):
    return sens/(1-spec)

def lr_neg(sens, spec):
    return (1-sens)/spec

df['LR (+)'] = lr_pos(df['Mx Sensitivity'], df['Specificity'])
df['LR (-)'] = lr_neg(df['Mx Sensitivity'], df['Specificity'])

# %%
df
# Out:
#     Dx ID Mx ID Dx Mx Association                                    Dx Name  \
# 0     362    59           362, 59                               PEPTIC ULCER
# 1     362    62           362, 62                               PEPTIC ULCER
# 2     362    64           362, 64                               PEPTIC ULCER
# 3     362   198          362, 198                               PEPTIC ULCER
# 4     362   199          362, 199                               PEPTIC ULCER
# 5     362   200          362, 200                               PEPTIC ULCER
# 6     362   208          362, 208                               PEPTIC ULCER
# 7     362   391          362, 391                               PEPTIC ULCER
# 8     362   957          362, 957                               PEPTIC ULCER
# 9     362  1046         362, 1046                               PEPTIC ULCER
# 10    362  1581         362, 1581                               PEPTIC ULCER
# 11    362  1889         362, 1889                               PEPTIC ULCER
# 12    362  3304         362, 3304                               PEPTIC ULCER
# 13    362  3305         362, 3305                               PEPTIC ULCER
# 14    362  3915         362, 3915                               PEPTIC ULCER
# 15    362  3916         362, 3916                               PEPTIC ULCER
# 16    362  4061         362, 4061                               PEPTIC ULCER
# 17    362    56           362, 56                               PEPTIC ULCER
# 18    362    58           362, 58                               PEPTIC ULCER
# 19    362    60           362, 60                               PEPTIC ULCER
# 20    362    61           362, 61                               PEPTIC ULCER
# 21    362    75           362, 75                               PEPTIC ULCER
# 22    362    76           362, 76                               PEPTIC ULCER
# 23    362    77           362, 77                               PEPTIC ULCER
# 24    362    78           362, 78                               PEPTIC ULCER
# 25    362    85           362, 85                               PEPTIC ULCER
# 26    362    88           362, 88                               PEPTIC ULCER
# 27    362    89           362, 89                               PEPTIC ULCER
# 28    362    92           362, 92                               PEPTIC ULCER
# 29    362   248          362, 248                               PEPTIC ULCER
# ..    ...   ...               ...                                        ...
# 721   189    58           189, 58  GASTRITIS GIANT HYPERTROPHIC <MENETRIERS>
# 722   189    75           189, 75  GASTRITIS GIANT HYPERTROPHIC <MENETRIERS>
# 723   189    78           189, 78  GASTRITIS GIANT HYPERTROPHIC <MENETRIERS>
# 724   189   248          189, 248  GASTRITIS GIANT HYPERTROPHIC <MENETRIERS>
# 725   189  4022         189, 4022  GASTRITIS GIANT HYPERTROPHIC <MENETRIERS>
# 726   189   102          189, 102  GASTRITIS GIANT HYPERTROPHIC <MENETRIERS>
# 727   189   108          189, 108  GASTRITIS GIANT HYPERTROPHIC <MENETRIERS>
# 728   189  1512         189, 1512  GASTRITIS GIANT HYPERTROPHIC <MENETRIERS>
# 729   189  3688         189, 3688  GASTRITIS GIANT HYPERTROPHIC <MENETRIERS>
# 730   189  3711         189, 3711  GASTRITIS GIANT HYPERTROPHIC <MENETRIERS>
# 731   189  3720         189, 3720  GASTRITIS GIANT HYPERTROPHIC <MENETRIERS>
# 732   189    63           189, 63  GASTRITIS GIANT HYPERTROPHIC <MENETRIERS>
# 733   189    68           189, 68  GASTRITIS GIANT HYPERTROPHIC <MENETRIERS>
# 734   189  3448         189, 3448  GASTRITIS GIANT HYPERTROPHIC <MENETRIERS>
# 735   189  4019         189, 4019  GASTRITIS GIANT HYPERTROPHIC <MENETRIERS>
# 736   189  1891         189, 1891  GASTRITIS GIANT HYPERTROPHIC <MENETRIERS>
# 737   189  1897         189, 1897  GASTRITIS GIANT HYPERTROPHIC <MENETRIERS>
# 738   189  1892         189, 1892  GASTRITIS GIANT HYPERTROPHIC <MENETRIERS>
# 739   189  3128         189, 3128  GASTRITIS GIANT HYPERTROPHIC <MENETRIERS>
# 740   189  1887         189, 1887  GASTRITIS GIANT HYPERTROPHIC <MENETRIERS>
# 741   189  1904         189, 1904  GASTRITIS GIANT HYPERTROPHIC <MENETRIERS>
# 742   189  1021         189, 1021  GASTRITIS GIANT HYPERTROPHIC <MENETRIERS>
# 743   189  1495         189, 1495  GASTRITIS GIANT HYPERTROPHIC <MENETRIERS>
# 744   189  1888         189, 1888  GASTRITIS GIANT HYPERTROPHIC <MENETRIERS>
# 745   189   205          189, 205  GASTRITIS GIANT HYPERTROPHIC <MENETRIERS>
# 746   189  3690         189, 3690  GASTRITIS GIANT HYPERTROPHIC <MENETRIERS>
# 747   189  3698         189, 3698  GASTRITIS GIANT HYPERTROPHIC <MENETRIERS>
# 748   189  3728         189, 3728  GASTRITIS GIANT HYPERTROPHIC <MENETRIERS>
# 749   189  1152         189, 1152  GASTRITIS GIANT HYPERTROPHIC <MENETRIERS>
# 750   189  3729         189, 3729  GASTRITIS GIANT HYPERTROPHIC <MENETRIERS>
#
#                                                Mx Name  Mx PPV  \
# 0     ABDOMEN PAIN EPIGASTRIUM RECURRENT ATTACK <S> HX    0.75
# 1                 ABDOMEN PAIN EPIGASTRIUM SEASONAL HX    0.10
# 2               ABDOMEN PAIN EXACERBATION WITH ALCOHOL    0.10
# 3                                         AGE 16 TO 25     NaN
# 4                                         AGE 26 TO 55     NaN
# 5                                      AGE GTR THAN 55     NaN
# 6                                ALCOHOLISM CHRONIC HX    0.10
# 7     ASPIRIN ADMINISTRATION IN LARGE AMOUNT RECENT HX    0.01
# 8                                 CIGARETTE SMOKING HX     NaN
# 9    CORTICOSTEROID ADMINISTRATION PRIOR TO CURRENT...    0.10
# 10                                      GASTRECTOMY HX    0.10
# 11                                      HEMATEMESIS HX    0.10
# 12                                          SEX FEMALE     NaN
# 13                                            SEX MALE     NaN
# 14                              ULCER PEPTIC FAMILY HX    0.10
# 15                                     ULCER PEPTIC HX    0.10
# 16                     WEIGHT LOSS GTR THAN 10 PERCENT     NaN
# 17                                ABDOMEN PAIN CHRONIC    0.10
# 18                            ABDOMEN PAIN EPIGASTRIUM    0.75
# 19        ABDOMEN PAIN EPIGASTRIUM RELIEVED BY ANTACID    0.10
# 20           ABDOMEN PAIN EPIGASTRIUM RELIEVED BY FOOD    0.75
# 21                            ABDOMEN PAIN NON COLICKY    0.10
# 22     ABDOMEN PAIN ONSET GTR THAN 1 HOUR POSTPRANDIAL    0.75
# 23                          ABDOMEN PAIN PERIUMBILICAL    0.01
# 24                                ABDOMEN PAIN PRESENT     NaN
# 25                    ABDOMEN PAIN RELIEVED BY FASTING    0.01
# 26                   ABDOMEN PAIN RIGHT LOWER QUADRANT    0.01
# 27                   ABDOMEN PAIN RIGHT UPPER QUADRANT    0.01
# 28                                 ABDOMEN PAIN SEVERE    0.01
# 29                                            ANOREXIA     NaN
# ..                                                 ...     ...
# 721                           ABDOMEN PAIN EPIGASTRIUM    0.01
# 722                           ABDOMEN PAIN NON COLICKY    0.01
# 723                               ABDOMEN PAIN PRESENT     NaN
# 724                                           ANOREXIA     NaN
# 725                                    VOMITING RECENT     NaN
# 726       ABDOMEN TENDERNESS EPIGASTRIUM <NON HEPATIC>    0.01
# 727                         ABDOMEN TENDERNESS PRESENT     NaN
# 728                         FECES GUAIAC TEST POSITIVE    0.01
# 729  STOMACH ACIDITY AFTER PENTAGASTRIN 30 TO 40 ME...    0.01
# 730                 STOMACH BARIUM MEAL RUGAE ENLARGED    0.10
# 731             STOMACH ENDOSCOPY DIFFUSE INFLAMMATION    0.01
# 732     ABDOMEN PAIN EPIGASTRIUM UNRELIEVED BY ANTACID    0.01
# 733                ABDOMEN PAIN EXACERBATION WITH FOOD    0.01
# 734                            SKIN PALLOR GENERALIZED     NaN
# 735                             VOMITING COFFEE GROUND    0.01
# 736                      HEMATOCRIT BLOOD LESS THAN 35    0.01
# 737                      HEMOGLOBIN BLOOD LESS THAN 12    0.01
# 738                    HEMATOCRIT BLOOD RAPID DECREASE    0.01
# 739                             RACE WHITE <CAUCASIAN>     NaN
# 740                HEMATEMESIS AFTER FORCEFUL VOMITING    0.01
# 741        HEMORRHAGE GASTROINTESTINAL ACUTE RECENT HX    0.01
# 742                    CONJUNCTIVA AND/OR MOUTH PALLOR    0.01
# 743                                  FECES BLACK TARRY    0.01
# 744                                  HEMATEMESIS GROSS    0.01
# 745          ALBUMIN SERUM LESS THAN 3 GRAM <S> PER DL    0.01
# 746   STOMACH ACIDITY AFTER PENTAGASTRIN PH GTR THAN 6    0.01
# 747                       STOMACH ASPIRATE GROSS BLOOD    0.01
# 748                   STOMACH ENDOSCOPY RUGAE ENLARGED    0.10
# 749                                   DIARRHEA CHRONIC    0.01
# 750  STOMACH ENDOSCOPY RUGAE ENLARGED AFTER AIR INS...    0.75
#
#      Mx Sensitivity  Specificity         LR (+)    LR (-)  Import Num  \
# 0              0.75     0.982143      42.000000  0.254545           2
# 1              0.10     0.935714       1.555556  0.961832           2
# 2              0.50     0.678571       1.555556  0.736842           2
# 3              0.10          NaN            NaN       NaN           3
# 4              0.50          NaN            NaN       NaN           3
# 5              0.10          NaN            NaN       NaN           3
# 6              0.10     0.935714       1.555556  0.961832           3
# 7              0.10     0.292857       0.141414  3.073171           1
# 8              0.10          NaN            NaN       NaN           1
# 9              0.01     0.993571       1.555556  0.996405           2
# 10             0.10     0.935714       1.555556  0.961832           3
# 11             0.10     0.935714       1.555556  0.961832           3
# 12             0.10          NaN            NaN       NaN           3
# 13             0.75          NaN            NaN       NaN           3
# 14             0.10     0.935714       1.555556  0.961832           2
# 15             0.50     0.678571       1.555556  0.736842           2
# 16             0.01          NaN            NaN       NaN           3
# 17             0.75     0.517857       1.555556  0.482759           3
# 18             0.75     0.982143      42.000000  0.254545           3
# 19             0.75     0.517857       1.555556  0.482759           2
# 20             0.75     0.982143      42.000000  0.254545           2
# 21             0.75     0.517857       1.555556  0.482759           3
# 22             0.75     0.982143      42.000000  0.254545           3
# 23             0.10     0.292857       0.141414  3.073171           3
# 24             0.75          NaN            NaN       NaN           2
# 25             0.10     0.292857       0.141414  3.073171           2
# 26             0.01     0.929286       0.141414  1.065334           3
# 27             0.01     0.929286       0.141414  1.065334           3
# 28             0.01     0.929286       0.141414  1.065334           3
# 29             0.01          NaN            NaN       NaN           1
# ..              ...          ...            ...       ...         ...
# 721            0.50     0.999505    1010.090909  0.500248           3
# 722            0.50     0.999505    1010.090909  0.500248           3
# 723            0.50          NaN            NaN       NaN           2
# 724            0.10          NaN            NaN       NaN           1
# 725            0.10          NaN            NaN       NaN           2
# 726            0.10     0.999901    1010.090909  0.900089           3
# 727            0.10          NaN            NaN       NaN           2
# 728            0.75     0.999257    1010.090909  0.250186           3
# 729            0.10     0.999901    1010.090909  0.900089           3
# 730            1.00     0.999910   11111.000000  0.000000           3
# 731            0.10     0.999901    1010.090909  0.900089           2
# 732            0.50     0.999505    1010.090909  0.500248           3
# 733            0.50     0.999505    1010.090909  0.500248           2
# 734            0.10          NaN            NaN       NaN           2
# 735            0.10     0.999901    1010.090909  0.900089           3
# 736            0.10     0.999901    1010.090909  0.900089           3
# 737            0.10     0.999901    1010.090909  0.900089           3
# 738            0.01     0.999990    1010.090909  0.990010           5
# 739            0.75          NaN            NaN       NaN           2
# 740            0.01     0.999990    1010.090909  0.990010           4
# 741            0.01     0.999990    1010.090909  0.990010           3
# 742            0.10     0.999901    1010.090909  0.900089           2
# 743            0.10     0.999901    1010.090909  0.900089           4
# 744            0.10     0.999901    1010.090909  0.900089           4
# 745            0.10     0.999901    1010.090909  0.900089           3
# 746            0.50     0.999505    1010.090909  0.500248           3
# 747            0.10     0.999901    1010.090909  0.900089           3
# 748            1.00     0.999910   11111.000000  0.000000           3
# 749            0.10     0.999901    1010.090909  0.900089           3
# 750            1.00     0.999997  299996.999998  0.000000           4
#
#      Dx Prevalence
# 0         0.066667
# 1         0.066667
# 2         0.066667
# 3         0.066667
# 4         0.066667
# 5         0.066667
# 6         0.066667
# 7         0.066667
# 8         0.066667
# 9         0.066667
# 10        0.066667
# 11        0.066667
# 12        0.066667
# 13        0.066667
# 14        0.066667
# 15        0.066667
# 16        0.066667
# 17        0.066667
# 18        0.066667
# 19        0.066667
# 20        0.066667
# 21        0.066667
# 22        0.066667
# 23        0.066667
# 24        0.066667
# 25        0.066667
# 26        0.066667
# 27        0.066667
# 28        0.066667
# 29        0.066667
# ..             ...
# 721       0.000010
# 722       0.000010
# 723       0.000010
# 724       0.000010
# 725       0.000010
# 726       0.000010
# 727       0.000010
# 728       0.000010
# 729       0.000010
# 730       0.000010
# 731       0.000010
# 732       0.000010
# 733       0.000010
# 734       0.000010
# 735       0.000010
# 736       0.000010
# 737       0.000010
# 738       0.000010
# 739       0.000010
# 740       0.000010
# 741       0.000010
# 742       0.000010
# 743       0.000010
# 744       0.000010
# 745       0.000010
# 746       0.000010
# 747       0.000010
# 748       0.000010
# 749       0.000010
# 750       0.000010
#
# [751 rows x 12 columns]

# %%
# exploring which negative values are present (and possibly need to be corrected)
negs = df.loc[df['LR (-)'] < 0]
negs
# Out:
# Empty DataFrame
# Columns: [Dx ID, Mx ID, Dx Mx Association, Dx Name, Mx Name, Mx PPV, Mx Sensitivity, Specificity, LR (+), LR (-), Import Num, Dx Prevalence]
# Index: []

# %%
# create neater version for exporting as CSV

df_final = pd.DataFrame()

df_final['Association'] = df['Dx Mx Association']
df_final['Dx Name'] = df['Dx Name']
df_final['Mx Name'] = df['Mx Name']
df_final['Prevalence'] = df['Dx Prevalence']
df_final['Import'] = df['Import Num']
df_final['LR (+)'] = df['LR (+)']
df_final['LR (-)'] = df['LR (-)']

df_final.head()
# Out:
#   Association       Dx Name                                           Mx Name  \
# 0     362, 59  PEPTIC ULCER  ABDOMEN PAIN EPIGASTRIUM RECURRENT ATTACK <S> HX
# 1     362, 62  PEPTIC ULCER              ABDOMEN PAIN EPIGASTRIUM SEASONAL HX
# 2     362, 64  PEPTIC ULCER            ABDOMEN PAIN EXACERBATION WITH ALCOHOL
# 3    362, 198  PEPTIC ULCER                                      AGE 16 TO 25
# 4    362, 199  PEPTIC ULCER                                      AGE 26 TO 55
#
#    Prevalence  Import     LR (+)    LR (-)
# 0    0.066667       2  42.000000  0.254545
# 1    0.066667       2   1.555556  0.961832
# 2    0.066667       2   1.555556  0.736842
# 3    0.066667       3        NaN       NaN
# 4    0.066667       3        NaN       NaN

# %%
# export df_final
df_final.to_csv('DxMxLR.csv')

# %%
all_assocs = pd.read_csv('all_assocs.csv')

df_all = pd.DataFrame()

all_assocs.head()
# Out:
#    dx_id              dx_name  mx_id  \
# 0    114  CHOLEDOCHOLITHIASIS      5
# 1    114  CHOLEDOCHOLITHIASIS      6
# 2    114  CHOLEDOCHOLITHIASIS     18
# 3    114  CHOLEDOCHOLITHIASIS     19
# 4    114  CHOLEDOCHOLITHIASIS     32
#
#                                              mx_name associations
# 0                              ABDOMEN BRUIT PRESENT        114,5
# 1                 ABDOMEN BRUIT SYSTOLIC EPIGASTRIUM        114,6
# 2  ABDOMEN COMPUTERIZED TOMOGRAPHY ADRENAL MASS <...       114,18
# 3  ABDOMEN COMPUTERIZED TOMOGRAPHY ADRENAL MASS U...       114,19
# 4                                 ABDOMEN DISTENTION       114,32

# %%
#df_all['Association'] = all_assocs['associations']

df_all['Dx Name'] = all_assocs['dx_name']
df_all['Mx Name'] = all_assocs['mx_name']

#df_all['Prevalence'] = 0
#df_all['Import'] = 0
#df_all['LR(+)'] = 1
#df_all['LR(-)'] = 1

df_all.head()
# Out:
#                Dx Name                                            Mx Name
# 0  CHOLEDOCHOLITHIASIS                              ABDOMEN BRUIT PRESENT
# 1  CHOLEDOCHOLITHIASIS                 ABDOMEN BRUIT SYSTOLIC EPIGASTRIUM
# 2  CHOLEDOCHOLITHIASIS  ABDOMEN COMPUTERIZED TOMOGRAPHY ADRENAL MASS <...
# 3  CHOLEDOCHOLITHIASIS  ABDOMEN COMPUTERIZED TOMOGRAPHY ADRENAL MASS U...
# 4  CHOLEDOCHOLITHIASIS                                 ABDOMEN DISTENTION

# %%
df_test = df_all.merge(df_final, how = 'left', on = ['Dx Name', 'Mx Name'])

# %%
df_test = df_test.drop(['Prevalence'], axis=1)
df_test = df_test.drop(['Association'], axis=1)

df_test.head()
# Out:
#                Dx Name                                            Mx Name  \
# 0  CHOLEDOCHOLITHIASIS                              ABDOMEN BRUIT PRESENT
# 1  CHOLEDOCHOLITHIASIS                 ABDOMEN BRUIT SYSTOLIC EPIGASTRIUM
# 2  CHOLEDOCHOLITHIASIS  ABDOMEN COMPUTERIZED TOMOGRAPHY ADRENAL MASS <...
# 3  CHOLEDOCHOLITHIASIS  ABDOMEN COMPUTERIZED TOMOGRAPHY ADRENAL MASS U...
# 4  CHOLEDOCHOLITHIASIS                                 ABDOMEN DISTENTION
#
#    Import  LR (+)  LR (-)
# 0     NaN     NaN     NaN
# 1     NaN     NaN     NaN
# 2     NaN     NaN     NaN
# 3     NaN     NaN     NaN
# 4     NaN     NaN     NaN

# %%
df_prev.head()
# Out:
#   Dx ID  Dx Prevalence                                    Dx Name
# 0   114              3                        choledocholithiasis
# 1   362              5                               peptic ulcer
# 2   441              2                        pyloric obstruction
# 3   187              3                          gastric carcinoma
# 4   189              2  gastritis giant hypertrophic <menetriers>

# %%
df_prev['Dx Name'] = df_prev['Dx Name'].str.upper()

df_prev
# Out:
#   Dx ID  Dx Prevalence                                    Dx Name
# 0   114              3                        CHOLEDOCHOLITHIASIS
# 1   362              5                               PEPTIC ULCER
# 2   441              2                        PYLORIC OBSTRUCTION
# 3   187              3                          GASTRIC CARCINOMA
# 4   189              2  GASTRITIS GIANT HYPERTROPHIC <MENETRIERS>
# 5   351              4                         PANCREATITIS ACUTE
# 6   352              3                       PANCREATITIS CHRONIC
# 7   188              2                           GASTRIC LYMPHOMA
# 8   192              2               GASTROINTESTINAL SARCOIDOSIS
# 9   616              1                                ANISAKIASIS

# %%
df_test = pd.merge(df_test, df_prev[['Dx Name', 'Dx Prevalence']], how='left', on='Dx Name')

df_test
# Out:
#                   Dx Name                                            Mx Name  \
# 0     CHOLEDOCHOLITHIASIS                              ABDOMEN BRUIT PRESENT
# 1     CHOLEDOCHOLITHIASIS                 ABDOMEN BRUIT SYSTOLIC EPIGASTRIUM
# 2     CHOLEDOCHOLITHIASIS  ABDOMEN COMPUTERIZED TOMOGRAPHY ADRENAL MASS <...
# 3     CHOLEDOCHOLITHIASIS  ABDOMEN COMPUTERIZED TOMOGRAPHY ADRENAL MASS U...
# 4     CHOLEDOCHOLITHIASIS                                 ABDOMEN DISTENTION
# 5     CHOLEDOCHOLITHIASIS             ABDOMEN GUARDING INVOLUNTARY LOCALIZED
# 6     CHOLEDOCHOLITHIASIS      ABDOMEN MASS <ES> PRESENT <NON HEPATOSPLENIC>
# 7     CHOLEDOCHOLITHIASIS                           ABDOMEN MASS EPIGASTRIUM
# 8     CHOLEDOCHOLITHIASIS     ABDOMEN MASS LEFT UPPER QUADRANT <NON SPLENIC>
# 9     CHOLEDOCHOLITHIASIS                  ABDOMEN MASS RIGHT LOWER QUADRANT
# 10    CHOLEDOCHOLITHIASIS    ABDOMEN MASS RIGHT UPPER QUADRANT <NON HEPATIC>
# 11    CHOLEDOCHOLITHIASIS                                 ABDOMEN PAIN ACUTE
# 12    CHOLEDOCHOLITHIASIS                               ABDOMEN PAIN CHRONIC
# 13    CHOLEDOCHOLITHIASIS                               ABDOMEN PAIN COLICKY
# 14    CHOLEDOCHOLITHIASIS                           ABDOMEN PAIN EPIGASTRIUM
# 15    CHOLEDOCHOLITHIASIS   ABDOMEN PAIN EPIGASTRIUM RECURRENT ATTACK <S> HX
# 16    CHOLEDOCHOLITHIASIS       ABDOMEN PAIN EPIGASTRIUM RELIEVED BY ANTACID
# 17    CHOLEDOCHOLITHIASIS          ABDOMEN PAIN EPIGASTRIUM RELIEVED BY FOOD
# 18    CHOLEDOCHOLITHIASIS               ABDOMEN PAIN EPIGASTRIUM SEASONAL HX
# 19    CHOLEDOCHOLITHIASIS     ABDOMEN PAIN EPIGASTRIUM UNRELIEVED BY ANTACID
# 20    CHOLEDOCHOLITHIASIS             ABDOMEN PAIN EXACERBATION WITH ALCOHOL
# 21    CHOLEDOCHOLITHIASIS           ABDOMEN PAIN EXACERBATION WITH BREATHING
# 22    CHOLEDOCHOLITHIASIS               ABDOMEN PAIN EXACERBATION WITH COUGH
# 23    CHOLEDOCHOLITHIASIS                ABDOMEN PAIN EXACERBATION WITH FOOD
# 24    CHOLEDOCHOLITHIASIS              ABDOMEN PAIN EXACERBATION WITH MOTION
# 25    CHOLEDOCHOLITHIASIS                          ABDOMEN PAIN HYPOGASTRIUM
# 26    CHOLEDOCHOLITHIASIS                   ABDOMEN PAIN LEFT LOWER QUADRANT
# 27    CHOLEDOCHOLITHIASIS                   ABDOMEN PAIN LEFT UPPER QUADRANT
# 28    CHOLEDOCHOLITHIASIS                           ABDOMEN PAIN NON COLICKY
# 29    CHOLEDOCHOLITHIASIS    ABDOMEN PAIN ONSET GTR THAN 1 HOUR POSTPRANDIAL
# ...                   ...                                                ...
# 3500          ANISAKIASIS             STOMACH ENDOSCOPY DIFFUSE INFLAMMATION
# 3501          ANISAKIASIS               STOMACH ENDOSCOPY GASTRIC WALL RIGID
# 3502          ANISAKIASIS                             STOMACH ENDOSCOPY MASS
# 3503          ANISAKIASIS                   STOMACH ENDOSCOPY RUGAE ENLARGED
# 3504          ANISAKIASIS  STOMACH ENDOSCOPY RUGAE ENLARGED AFTER AIR INS...
# 3505          ANISAKIASIS                 STOMACH ENDOSCOPY ULCER CRATER <S>
# 3506          ANISAKIASIS                          STOMACH SUCCUSSION SPLASH
# 3507          ANISAKIASIS                        STOMACH VISIBLE PERISTALSIS
# 3508          ANISAKIASIS               SYNOVIUM BIOPSY CHRONIC INFLAMMATION
# 3509          ANISAKIASIS                                        TACHYCARDIA
# 3510          ANISAKIASIS                                          TACHYPNEA
# 3511          ANISAKIASIS                   TRANSAMINASE <S> SERUM INCREASED
# 3512          ANISAKIASIS                   TRIGLYCERIDE <S> SERUM INCREASED
# 3513          ANISAKIASIS                             TROUSSEAU SIGN PRESENT
# 3514          ANISAKIASIS                             ULCER PEPTIC FAMILY HX
# 3515          ANISAKIASIS                                    ULCER PEPTIC HX
# 3516          ANISAKIASIS                               UMBILICUS NODULE <S>
# 3517          ANISAKIASIS                       UREA NITROGEN SERUM 30 TO 59
# 3518          ANISAKIASIS                                      URINE DARK HX
# 3519          ANISAKIASIS                                 URINE SEDIMENT RBC
# 3520          ANISAKIASIS                          UROBILINOGEN URINE ABSENT
# 3521          ANISAKIASIS                       UROBILINOGEN URINE INCREASED
# 3522          ANISAKIASIS                             VOMITING COFFEE GROUND
# 3523          ANISAKIASIS                                    VOMITING RECENT
# 3524          ANISAKIASIS                    VOMITING RECURRENT SELF INDUCED
# 3525          ANISAKIASIS                                 WBC 14000 TO 30000
# 3526          ANISAKIASIS  WBC 4000 TO 13900 PERCENT NEUTROPHIL <S> INCRE...
# 3527          ANISAKIASIS                    WBC EOSINOPHIL <S> GTR THAN 400
# 3528          ANISAKIASIS                                 WBC GTR THAN 30000
# 3529          ANISAKIASIS                    WEIGHT LOSS GTR THAN 10 PERCENT
#
#       Import        LR (+)    LR (-)  Dx Prevalence
# 0        NaN           NaN       NaN              3
# 1        NaN           NaN       NaN              3
# 2        NaN           NaN       NaN              3
# 3        NaN           NaN       NaN              3
# 4        NaN           NaN       NaN              3
# 5        NaN           NaN       NaN              3
# 6        NaN           NaN       NaN              3
# 7        NaN           NaN       NaN              3
# 8        NaN           NaN       NaN              3
# 9        NaN           NaN       NaN              3
# 10       NaN           NaN       NaN              3
# 11       3.0    111.000000  0.502262              3
# 12       NaN           NaN       NaN              3
# 13       3.0    111.000000  0.502262              3
# 14       3.0    111.000000  0.502262              3
# 15       2.0    111.000000  0.900812              3
# 16       NaN           NaN       NaN              3
# 17       NaN           NaN       NaN              3
# 18       NaN           NaN       NaN              3
# 19       3.0    111.000000  0.502262              3
# 20       NaN           NaN       NaN              3
# 21       NaN           NaN       NaN              3
# 22       NaN           NaN       NaN              3
# 23       2.0     10.090909  0.909008              3
# 24       NaN           NaN       NaN              3
# 25       NaN           NaN       NaN              3
# 26       NaN           NaN       NaN              3
# 27       NaN           NaN       NaN              3
# 28       NaN           NaN       NaN              3
# 29       NaN           NaN       NaN              3
# ...      ...           ...       ...            ...
# 3500     NaN           NaN       NaN              1
# 3501     NaN           NaN       NaN              1
# 3502     4.0  10101.000000  0.900009              1
# 3503     3.0  10101.000000  0.900009              1
# 3504     NaN           NaN       NaN              1
# 3505     NaN           NaN       NaN              1
# 3506     NaN           NaN       NaN              1
# 3507     NaN           NaN       NaN              1
# 3508     NaN           NaN       NaN              1
# 3509     NaN           NaN       NaN              1
# 3510     NaN           NaN       NaN              1
# 3511     NaN           NaN       NaN              1
# 3512     NaN           NaN       NaN              1
# 3513     NaN           NaN       NaN              1
# 3514     NaN           NaN       NaN              1
# 3515     NaN           NaN       NaN              1
# 3516     NaN           NaN       NaN              1
# 3517     NaN           NaN       NaN              1
# 3518     NaN           NaN       NaN              1
# 3519     NaN           NaN       NaN              1
# 3520     NaN           NaN       NaN              1
# 3521     NaN           NaN       NaN              1
# 3522     NaN           NaN       NaN              1
# 3523     2.0           NaN       NaN              1
# 3524     NaN           NaN       NaN              1
# 3525     NaN           NaN       NaN              1
# 3526     2.0           NaN       NaN              1
# 3527     2.0  10101.000000  0.900009              1
# 3528     NaN           NaN       NaN              1
# 3529     NaN           NaN       NaN              1
#
# [3530 rows x 6 columns]

# %%
df_test['LR (+)'] = df_test['LR (+)'].fillna(value = 1)
df_test['LR (-)'] = df_test['LR (-)'].fillna(value = 1)

# convert prevalances back to proportions
# adding new column to be consistent with original DxMxLR.csv file
df_test['Prevalence'] = df_test['Dx Prevalence'].map(PREV)

df_test
# Out:
#                   Dx Name                                            Mx Name  \
# 0     CHOLEDOCHOLITHIASIS                              ABDOMEN BRUIT PRESENT
# 1     CHOLEDOCHOLITHIASIS                 ABDOMEN BRUIT SYSTOLIC EPIGASTRIUM
# 2     CHOLEDOCHOLITHIASIS  ABDOMEN COMPUTERIZED TOMOGRAPHY ADRENAL MASS <...
# 3     CHOLEDOCHOLITHIASIS  ABDOMEN COMPUTERIZED TOMOGRAPHY ADRENAL MASS U...
# 4     CHOLEDOCHOLITHIASIS                                 ABDOMEN DISTENTION
# 5     CHOLEDOCHOLITHIASIS             ABDOMEN GUARDING INVOLUNTARY LOCALIZED
# 6     CHOLEDOCHOLITHIASIS      ABDOMEN MASS <ES> PRESENT <NON HEPATOSPLENIC>
# 7     CHOLEDOCHOLITHIASIS                           ABDOMEN MASS EPIGASTRIUM
# 8     CHOLEDOCHOLITHIASIS     ABDOMEN MASS LEFT UPPER QUADRANT <NON SPLENIC>
# 9     CHOLEDOCHOLITHIASIS                  ABDOMEN MASS RIGHT LOWER QUADRANT
# 10    CHOLEDOCHOLITHIASIS    ABDOMEN MASS RIGHT UPPER QUADRANT <NON HEPATIC>
# 11    CHOLEDOCHOLITHIASIS                                 ABDOMEN PAIN ACUTE
# 12    CHOLEDOCHOLITHIASIS                               ABDOMEN PAIN CHRONIC
# 13    CHOLEDOCHOLITHIASIS                               ABDOMEN PAIN COLICKY
# 14    CHOLEDOCHOLITHIASIS                           ABDOMEN PAIN EPIGASTRIUM
# 15    CHOLEDOCHOLITHIASIS   ABDOMEN PAIN EPIGASTRIUM RECURRENT ATTACK <S> HX
# 16    CHOLEDOCHOLITHIASIS       ABDOMEN PAIN EPIGASTRIUM RELIEVED BY ANTACID
# 17    CHOLEDOCHOLITHIASIS          ABDOMEN PAIN EPIGASTRIUM RELIEVED BY FOOD
# 18    CHOLEDOCHOLITHIASIS               ABDOMEN PAIN EPIGASTRIUM SEASONAL HX
# 19    CHOLEDOCHOLITHIASIS     ABDOMEN PAIN EPIGASTRIUM UNRELIEVED BY ANTACID
# 20    CHOLEDOCHOLITHIASIS             ABDOMEN PAIN EXACERBATION WITH ALCOHOL
# 21    CHOLEDOCHOLITHIASIS           ABDOMEN PAIN EXACERBATION WITH BREATHING
# 22    CHOLEDOCHOLITHIASIS               ABDOMEN PAIN EXACERBATION WITH COUGH
# 23    CHOLEDOCHOLITHIASIS                ABDOMEN PAIN EXACERBATION WITH FOOD
# 24    CHOLEDOCHOLITHIASIS              ABDOMEN PAIN EXACERBATION WITH MOTION
# 25    CHOLEDOCHOLITHIASIS                          ABDOMEN PAIN HYPOGASTRIUM
# 26    CHOLEDOCHOLITHIASIS                   ABDOMEN PAIN LEFT LOWER QUADRANT
# 27    CHOLEDOCHOLITHIASIS                   ABDOMEN PAIN LEFT UPPER QUADRANT
# 28    CHOLEDOCHOLITHIASIS                           ABDOMEN PAIN NON COLICKY
# 29    CHOLEDOCHOLITHIASIS    ABDOMEN PAIN ONSET GTR THAN 1 HOUR POSTPRANDIAL
# ...                   ...                                                ...
# 3500          ANISAKIASIS             STOMACH ENDOSCOPY DIFFUSE INFLAMMATION
# 3501          ANISAKIASIS               STOMACH ENDOSCOPY GASTRIC WALL RIGID
# 3502          ANISAKIASIS                             STOMACH ENDOSCOPY MASS
# 3503          ANISAKIASIS                   STOMACH ENDOSCOPY RUGAE ENLARGED
# 3504          ANISAKIASIS  STOMACH ENDOSCOPY RUGAE ENLARGED AFTER AIR INS...
# 3505          ANISAKIASIS                 STOMACH ENDOSCOPY ULCER CRATER <S>
# 3506          ANISAKIASIS                          STOMACH SUCCUSSION SPLASH
# 3507          ANISAKIASIS                        STOMACH VISIBLE PERISTALSIS
# 3508          ANISAKIASIS               SYNOVIUM BIOPSY CHRONIC INFLAMMATION
# 3509          ANISAKIASIS                                        TACHYCARDIA
# 3510          ANISAKIASIS                                          TACHYPNEA
# 3511          ANISAKIASIS                   TRANSAMINASE <S> SERUM INCREASED
# 3512          ANISAKIASIS                   TRIGLYCERIDE <S> SERUM INCREASED
# 3513          ANISAKIASIS                             TROUSSEAU SIGN PRESENT
# 3514          ANISAKIASIS                             ULCER PEPTIC FAMILY HX
# 3515          ANISAKIASIS                                    ULCER PEPTIC HX
# 3516          ANISAKIASIS                               UMBILICUS NODULE <S>
# 3517          ANISAKIASIS                       UREA NITROGEN SERUM 30 TO 59
# 3518          ANISAKIASIS                                      URINE DARK HX
# 3519          ANISAKIASIS                                 URINE SEDIMENT RBC
# 3520          ANISAKIASIS                          UROBILINOGEN URINE ABSENT
# 3521          ANISAKIASIS                       UROBILINOGEN URINE INCREASED
# 3522          ANISAKIASIS                             VOMITING COFFEE GROUND
# 3523          ANISAKIASIS                                    VOMITING RECENT
# 3524          ANISAKIASIS                    VOMITING RECURRENT SELF INDUCED
# 3525          ANISAKIASIS                                 WBC 14000 TO 30000
# 3526          ANISAKIASIS  WBC 4000 TO 13900 PERCENT NEUTROPHIL <S> INCRE...
# 3527          ANISAKIASIS                    WBC EOSINOPHIL <S> GTR THAN 400
# 3528          ANISAKIASIS                                 WBC GTR THAN 30000
# 3529          ANISAKIASIS                    WEIGHT LOSS GTR THAN 10 PERCENT
#
#       Import        LR (+)    LR (-)  Dx Prevalence  Prevalence
# 0        NaN      1.000000  1.000000              3    0.001000
# 1        NaN      1.000000  1.000000              3    0.001000
# 2        NaN      1.000000  1.000000              3    0.001000
# 3        NaN      1.000000  1.000000              3    0.001000
# 4        NaN      1.000000  1.000000              3    0.001000
# 5        NaN      1.000000  1.000000              3    0.001000
# 6        NaN      1.000000  1.000000              3    0.001000
# 7        NaN      1.000000  1.000000              3    0.001000
# 8        NaN      1.000000  1.000000              3    0.001000
# 9        NaN      1.000000  1.000000              3    0.001000
# 10       NaN      1.000000  1.000000              3    0.001000
# 11       3.0    111.000000  0.502262              3    0.001000
# 12       NaN      1.000000  1.000000              3    0.001000
# 13       3.0    111.000000  0.502262              3    0.001000
# 14       3.0    111.000000  0.502262              3    0.001000
# 15       2.0    111.000000  0.900812              3    0.001000
# 16       NaN      1.000000  1.000000              3    0.001000
# 17       NaN      1.000000  1.000000              3    0.001000
# 18       NaN      1.000000  1.000000              3    0.001000
# 19       3.0    111.000000  0.502262              3    0.001000
# 20       NaN      1.000000  1.000000              3    0.001000
# 21       NaN      1.000000  1.000000              3    0.001000
# 22       NaN      1.000000  1.000000              3    0.001000
# 23       2.0     10.090909  0.909008              3    0.001000
# 24       NaN      1.000000  1.000000              3    0.001000
# 25       NaN      1.000000  1.000000              3    0.001000
# 26       NaN      1.000000  1.000000              3    0.001000
# 27       NaN      1.000000  1.000000              3    0.001000
# 28       NaN      1.000000  1.000000              3    0.001000
# 29       NaN      1.000000  1.000000              3    0.001000
# ...      ...           ...       ...            ...         ...
# 3500     NaN      1.000000  1.000000              1    0.000001
# 3501     NaN      1.000000  1.000000              1    0.000001
# 3502     4.0  10101.000000  0.900009              1    0.000001
# 3503     3.0  10101.000000  0.900009              1    0.000001
# 3504     NaN      1.000000  1.000000              1    0.000001
# 3505     NaN      1.000000  1.000000              1    0.000001
# 3506     NaN      1.000000  1.000000              1    0.000001
# 3507     NaN      1.000000  1.000000              1    0.000001
# 3508     NaN      1.000000  1.000000              1    0.000001
# 3509     NaN      1.000000  1.000000              1    0.000001
# 3510     NaN      1.000000  1.000000              1    0.000001
# 3511     NaN      1.000000  1.000000              1    0.000001
# 3512     NaN      1.000000  1.000000              1    0.000001
# 3513     NaN      1.000000  1.000000              1    0.000001
# 3514     NaN      1.000000  1.000000              1    0.000001
# 3515     NaN      1.000000  1.000000              1    0.000001
# 3516     NaN      1.000000  1.000000              1    0.000001
# 3517     NaN      1.000000  1.000000              1    0.000001
# 3518     NaN      1.000000  1.000000              1    0.000001
# 3519     NaN      1.000000  1.000000              1    0.000001
# 3520     NaN      1.000000  1.000000              1    0.000001
# 3521     NaN      1.000000  1.000000              1    0.000001
# 3522     NaN      1.000000  1.000000              1    0.000001
# 3523     2.0      1.000000  1.000000              1    0.000001
# 3524     NaN      1.000000  1.000000              1    0.000001
# 3525     NaN      1.000000  1.000000              1    0.000001
# 3526     2.0      1.000000  1.000000              1    0.000001
# 3527     2.0  10101.000000  0.900009              1    0.000001
# 3528     NaN      1.000000  1.000000              1    0.000001
# 3529     NaN      1.000000  1.000000              1    0.000001
#
# [3530 rows x 7 columns]

# %%
df_test.to_csv('../df_bayes.csv')
